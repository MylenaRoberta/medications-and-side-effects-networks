# %% [markdown]
# # **Network Construction**
# Habit Forming Medications

# %% [markdown]
# # Import Libraries

# %%
import ast
from collections import defaultdict
from itertools import combinations

import pandas as pd

# %% [markdown]
# # Function

# %%
def calculate_jaccard_associations(neighbors):
    # Create a list to store the results
    results = list()

    # Compute the Jaccard index between each combination of different nodes
    for node_a, node_b in combinations(neighbors, 2):
        # Get the sets of neighbors from both nodes
        set_a = neighbors[node_a]
        set_b = neighbors[node_b]
        
        # Compute the Jaccard index between both sets
        intersection = len(set_a & set_b)
        union = len(set_a | set_b)
        jaccard = intersection / union if union else 0
        
        # Insert the result for this combination in the list
        results.append((node_a, node_b, jaccard))
    
    # Create a DataFrame for the inferred associations
    columns = ['source', 'target', 'association']
    df_associations = pd.DataFrame(results, columns=columns) \
        .sort_values(by='association', ascending=False) \
        .query('association > 0') \
        .reset_index(drop=True)
    
    return df_associations

# %% [markdown]
# # Load the Processed Dataset

# %%
# DataFrame with processed data about medications and side effects
df_medications = pd.read_csv('../data/processed/medicine-dataset.csv')

# Convert side effects and habit forming representations of sets to actual sets
df_medications['side_effects'] = \
    df_medications['side_effects'].apply(ast.literal_eval)
df_medications['habit_forming'] = \
    df_medications['habit_forming'].apply(ast.literal_eval)

# Print the DataFrame
df_medications
# Out:
#                               name  \
# 0                   a 1 5mg tablet
# 1                 a 250 suspension
# 2         a 3 100 mg/500 mg tablet
# 3            a arti 60mg injection
# 4       a arti l 80mg/480mg tablet
# ...                            ...
# 222820         zyxtil 500mg tablet
# 222821                 zyzer syrup
# 222822          zyzine 25mg tablet
# 222823       zyzolide 600mg tablet
# 222824        α-bert 150 injection
#
#                                              side_effects  \
# 0       {sleepiness, nausea, headache, fatigue, abdomi...
# 1           {nausea, stomach pain, vomiting, indigestion}
# 2       {increased liver enzymes, nausea, vomiting, di...
# 3       {injection site reactions (pain, swelling, red...
# 4       {joint pain, dizziness, weakness, loss of appe...
# ...                                                   ...
# 222820  {allergic reaction, diarrhea, nausea, rash, vo...
# 222821  {sleepiness, blurred vision, dryness in mouth,...
# 222822  {nausea, vomiting, constipation, upset stomach...
# 222823  {diarrhea, nausea, vomiting, decreased blood c...
# 222824  {nausea, injection site reactions (pain, swell...
#
#                                                      uses  \
# 0       {'prevention of angina (heart-related chest pa...
# 1                  {' pain relief', 'treatment of fever'}
# 2                                        {' pain relief'}
# 3                                            {' malaria'}
# 4                                {'treatment of malaria'}
# ...                                                   ...
# 222820              {'treatment of bacterial infections'}
# 222821                            {' appetite stimulant'}
# 222822  {'treatment of anxiety', 'treatment of skin co...
# 222823       {'treatment of severe bacterial infections'}
# 222824                                       {' malaria'}
#
#                                            chemical_class habit_forming  \
# 0         {'dihydropyridinecarboxylic acids derivatives'}          {no}
# 1                            {'p-aminophenol derivative'}          {no}
# 2                                                   {nan}          {no}
# 3                              {'sesquiterpene lactones'}          {no}
# 4                                                   {nan}          {no}
# ...                                                   ...           ...
# 222820  {'intermediate spectrum {second generation cep...          {no}
# 222821                                              {nan}          {no}
# 222822                          {'piperazine derivative'}          {no}
# 222823                       {'oxazolidinone derivative'}          {no}
# 222824                         {'sesquiterpene lactones'}          {no}
#
#                       therapeutic_class  \
# 0                           {'cardiac'}
# 1                   {'pain analgesics'}
# 2                   {'pain analgesics'}
# 3                    {'anti malarials'}
# 4                    {'anti malarials'}
# ...                                 ...
# 222820              {'anti infectives'}
# 222821  {'vitamins minerals nutrients'}
# 222822                  {'respiratory'}
# 222823              {'anti infectives'}
# 222824               {'anti malarials'}
#
#                                              action_class
# 0       {'calcium channel blockers- dihydropyridines (...
# 1                         {'analgesic & antipyretic-pcm'}
# 2                                                   {nan}
# 3           {'antimalarial- artemisinin and derivatives'}
# 4                                                   {nan}
# ...                                                   ...
# 222820                 {'cephalosporins: 2nd generation'}
# 222821                                              {nan}
# 222822          {'h1 antihistaminics (first generation)'}
# 222823                                  {'oxazolidinone'}
# 222824      {'antimalarial- artemisinin and derivatives'}
#
# [222825 rows x 7 columns]

# %% [markdown]
# # Bipartite Network

# %%
# Explode the side effects and habit forming columns
df_medications = df_medications \
    .explode(column='side_effects') \
    .explode(column='habit_forming')

# Filter the habit forming medications
df_medications = df_medications.query('habit_forming == "yes"')

# %%
# Create a DataFrame only for medications
df_meds = df_medications \
    .drop(columns='side_effects') \
    .rename(columns={'name': 'id'}) \
    .drop_duplicates() \
    .reset_index(drop=True)
df_meds['label'] = df_meds['id']
df_meds['type'] = 'medication'

# Print the DataFrame of medications
df_meds
# Out:
#                                       id  \
# 0                    a-tryp forte tablet
# 1                     aaram 0.5mg tablet
# 2                           aaram tablet
# 3                        abdocool tablet
# 4                 abidol 100mg injection
# ...                                  ...
# 5448        zytram p 37.5mg/325mg tablet
# 5449                    zytram pd tablet
# 5450                     zytramol tablet
# 5451  zyven od plus 100 mg/0.5 mg tablet
# 5452   zyven od plus 50 mg/0.5 mg tablet
#
#                                                    uses  \
# 0                           {'treatment of depression'}
# 1     {'treatment of anxiety', 'treatment of panic d...
# 2     {'treatment of anxiety', 'treatment of panic d...
# 3             {'treatment of irritable bowel syndrome'}
# 4                          {' moderate to severe pain'}
# ...                                                 ...
# 5448                       {' moderate to severe pain'}
# 5449  {'treatment of severe acute pain', 'treatment ...
# 5450                       {' moderate to severe pain'}
# 5451                        {'treatment of depression'}
# 5452                        {'treatment of depression'}
#
#                       chemical_class habit_forming      therapeutic_class  \
# 0                              {nan}           yes          {'neuro cns'}
# 1     {'benzodiazepines derivative'}           yes          {'neuro cns'}
# 2     {'benzodiazepines derivative'}           yes          {'neuro cns'}
# 3                              {nan}           yes  {'gastro intestinal'}
# 4             {'anisole derivative'}           yes    {'pain analgesics'}
# ...                              ...           ...                    ...
# 5448                           {nan}           yes    {'pain analgesics'}
# 5449                           {nan}           yes    {'pain analgesics'}
# 5450                           {nan}           yes    {'pain analgesics'}
# 5451                           {nan}           yes          {'neuro cns'}
# 5452                           {nan}           yes          {'neuro cns'}
#
#              action_class                               label        type
# 0                   {nan}                 a-tryp forte tablet  medication
# 1     {'benzodiazepines'}                  aaram 0.5mg tablet  medication
# 2     {'benzodiazepines'}                        aaram tablet  medication
# 3                   {nan}                     abdocool tablet  medication
# 4             {'opioids'}              abidol 100mg injection  medication
# ...                   ...                                 ...         ...
# 5448                {nan}        zytram p 37.5mg/325mg tablet  medication
# 5449                {nan}                    zytram pd tablet  medication
# 5450                {nan}                     zytramol tablet  medication
# 5451                {nan}  zyven od plus 100 mg/0.5 mg tablet  medication
# 5452                {nan}   zyven od plus 50 mg/0.5 mg tablet  medication
#
# [5453 rows x 8 columns]

# %%
# Create a DataFrame only for side effects
df_effects = df_medications \
    [['side_effects']] \
    .rename(columns={'side_effects': 'id'}) \
    .drop_duplicates() \
    .reset_index(drop=True)
df_effects['label'] = df_effects['id']
df_effects['type'] = 'side effect'

# Print the DataFrame of side effects
df_effects
# Out:
#                                id                         label         type
# 0                     weight gain                   weight gain  side effect
# 1               memory impairment             memory impairment  side effect
# 2         difficulty in urination       difficulty in urination  side effect
# 3                       tiredness                     tiredness  side effect
# 4                      depression                    depression  side effect
# ..                            ...                           ...          ...
# 127          circulatory disorder          circulatory disorder  side effect
# 128                cardiac arrest                cardiac arrest  side effect
# 129                         shock                         shock  side effect
# 130  apnea (absence of breathing)  apnea (absence of breathing)  side effect
# 131  muscle coordination impaired  muscle coordination impaired  side effect
#
# [132 rows x 3 columns]

# %%
# Create a DataFrame for the nodes
df_bipatite_nodes = pd.concat(
    objs=[df_meds, df_effects], ignore_index=True
)

# Store the DataFrame of bipartite network nodes
df_bipatite_nodes.to_csv(
    '../data/processed/bipartite-network-nodes.csv', index=False
)

# Print the DataFrame of bipartite network nodes
df_bipatite_nodes
# Out:
#                                 id  \
# 0              a-tryp forte tablet
# 1               aaram 0.5mg tablet
# 2                     aaram tablet
# 3                  abdocool tablet
# 4           abidol 100mg injection
# ...                            ...
# 5580          circulatory disorder
# 5581                cardiac arrest
# 5582                         shock
# 5583  apnea (absence of breathing)
# 5584  muscle coordination impaired
#
#                                                    uses  \
# 0                           {'treatment of depression'}
# 1     {'treatment of anxiety', 'treatment of panic d...
# 2     {'treatment of anxiety', 'treatment of panic d...
# 3             {'treatment of irritable bowel syndrome'}
# 4                          {' moderate to severe pain'}
# ...                                                 ...
# 5580                                                NaN
# 5581                                                NaN
# 5582                                                NaN
# 5583                                                NaN
# 5584                                                NaN
#
#                       chemical_class habit_forming      therapeutic_class  \
# 0                              {nan}           yes          {'neuro cns'}
# 1     {'benzodiazepines derivative'}           yes          {'neuro cns'}
# 2     {'benzodiazepines derivative'}           yes          {'neuro cns'}
# 3                              {nan}           yes  {'gastro intestinal'}
# 4             {'anisole derivative'}           yes    {'pain analgesics'}
# ...                              ...           ...                    ...
# 5580                             NaN           NaN                    NaN
# 5581                             NaN           NaN                    NaN
# 5582                             NaN           NaN                    NaN
# 5583                             NaN           NaN                    NaN
# 5584                             NaN           NaN                    NaN
#
#              action_class                         label         type
# 0                   {nan}           a-tryp forte tablet   medication
# 1     {'benzodiazepines'}            aaram 0.5mg tablet   medication
# 2     {'benzodiazepines'}                  aaram tablet   medication
# 3                   {nan}               abdocool tablet   medication
# 4             {'opioids'}        abidol 100mg injection   medication
# ...                   ...                           ...          ...
# 5580                  NaN          circulatory disorder  side effect
# 5581                  NaN                cardiac arrest  side effect
# 5582                  NaN                         shock  side effect
# 5583                  NaN  apnea (absence of breathing)  side effect
# 5584                  NaN  muscle coordination impaired  side effect
#
# [5585 rows x 8 columns]

# %%
# Create a DataFrame for the edges
df_bipatite_edges = df_medications \
    [['name', 'side_effects']] \
    .rename(columns={'name': 'source', 'side_effects': 'target'}) \
    .reset_index(drop=True)

# Store the DataFrame of bipartite network edges
df_bipatite_edges.to_csv(
    '../data/processed/bipartite-network-edges.csv', index=False
)

# Store the DataFrame of bipartite network edges
df_bipatite_edges
# Out:
#                                   source                        target
# 0                    a-tryp forte tablet                   weight gain
# 1                    a-tryp forte tablet             memory impairment
# 2                    a-tryp forte tablet       difficulty in urination
# 3                    a-tryp forte tablet                     tiredness
# 4                    a-tryp forte tablet                    depression
# ...                                  ...                           ...
# 45027  zyven od plus 50 mg/0.5 mg tablet  uncoordinated body movements
# 45028  zyven od plus 50 mg/0.5 mg tablet                  constipation
# 45029  zyven od plus 50 mg/0.5 mg tablet                      headache
# 45030  zyven od plus 50 mg/0.5 mg tablet                     confusion
# 45031  zyven od plus 50 mg/0.5 mg tablet             low sexual desire
#
# [45032 rows x 2 columns]

# %% [markdown]
# # Medication Projection

# %%
# # Determine the set of neighbors for each node
# neighbors = defaultdict(set)
# for _, row in df_bipatite_edges.iterrows():
#    neighbors[row['source']].add(row['target'])

# df_meds_proj = calculate_jaccard_associations(neighbors)

# %%
# df_meds_proj.query('association == 1')

# %% [markdown]
# # Side Effects Projection

# %%
# # Determine the set of neighbors for each node
# neighbors = defaultdict(set)
# for _, row in df_bipatite_edges.iterrows():
#    neighbors[row['target']].add(row['source'])

# df_effects_proj = calculate_jaccard_associations(neighbors)

# %%
# df_effects_proj.query('association == 1')
