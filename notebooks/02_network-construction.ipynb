# %% [markdown]
# # **Network Construction**

# %% [markdown]
# # Import Libraries

# %%
import ast
from collections import defaultdict
from itertools import combinations

import pandas as pd

# %% [markdown]
# # Function

# %%
def calculate_jaccard_associations(neighbors):
    # Create a list to store the results
    results = list()

    # Compute the Jaccard index between each combination of different nodes
    for node_a, node_b in combinations(neighbors, 2):
        # Get the sets of neighbors from both nodes
        set_a = neighbors[node_a]
        set_b = neighbors[node_b]
        
        # Compute the Jaccard index between both sets
        intersection = len(set_a & set_b)
        union = len(set_a | set_b)
        jaccard = intersection / union if union else 0
        
        # Insert the result for this combination in the list
        results.append((node_a, node_b, jaccard))
    
    # Create a DataFrame for the inferred associations
    columns = ['source', 'target', 'association']
    df_associations = pd.DataFrame(results, columns=columns) \
        .sort_values(by='association', ascending=False)
    
    return df_associations

# %% [markdown]
# # Load the Processed Dataset

# %%
# DataFrame with processed data about medications and side effects
df_medications = pd.read_csv('../data/processed/medicine-dataset.csv')

# Convert side effects representations of sets to actual sets
df_medications['side_effects'] = \
    df_medications['side_effects'].apply(ast.literal_eval)

# Print the DataFrame
df_medications
# Out:
#                                name  \
# 0       1 al plus 5mg/120mg capsule
# 1                      1 nvp tablet
# 2                    1-al 10 tablet
# 3                      1-al m syrup
# 4                        1-al syrup
# ...                             ...
# 230601          zyxtil 500mg tablet
# 230602                  zyzer syrup
# 230603           zyzine 25mg tablet
# 230604        zyzolide 600mg tablet
# 230605         α-bert 150 injection
#
#                                              side_effects  \
# 0       {sleepiness, headache, vomiting, dryness in mo...
# 1       {sleepiness, constipation, dryness in mouth, d...
# 2       {sleepiness, headache, nasopharyngitis (inflam...
# 3       {sleepiness, headache, skin rash, dryness in m...
# 4       {sleepiness, constipation, headache, nasophary...
# ...                                                   ...
# 230601  {vomiting, nausea, rash, allergic reaction, di...
# 230602  {sleepiness, constipation, dryness in mouth, d...
# 230603  {constipation, vomiting, sedation, nausea, ups...
# 230604  {headache, vomiting, nausea, decreased blood c...
# 230605  {headache, vomiting, nausea, abdominal pain, i...
#
#                                                      uses  \
# 0           {' sneezing and runny nose due to allergies'}
# 1       {'treatment of nausea and vomiting in pregnancy'}
# 2                    {'treatment of allergic conditions'}
# 3       {'treatment of sneezing and runny nose due to ...
# 4                    {'treatment of allergic conditions'}
# ...                                                   ...
# 230601              {'treatment of bacterial infections'}
# 230602                            {' appetite stimulant'}
# 230603  {'treatment of anxiety', 'treatment of skin co...
# 230604       {'treatment of severe bacterial infections'}
# 230605                                       {' malaria'}
#
#                                            chemical_class habit_forming  \
# 0                                                   {nan}        {'no'}
# 1                                                   {nan}        {'no'}
# 2                              {'piperazine derivatives'}        {'no'}
# 3                                                   {nan}        {'no'}
# 4                              {'piperazine derivatives'}        {'no'}
# ...                                                   ...           ...
# 230601  {'intermediate spectrum {second generation cep...        {'no'}
# 230602                                              {nan}        {'no'}
# 230603                          {'piperazine derivative'}        {'no'}
# 230604                       {'oxazolidinone derivative'}        {'no'}
# 230605                         {'sesquiterpene lactones'}        {'no'}
#
#                       therapeutic_class  \
# 0                       {'respiratory'}
# 1                 {'gastro intestinal'}
# 2                       {'respiratory'}
# 3                       {'respiratory'}
# 4                       {'respiratory'}
# ...                                 ...
# 230601              {'anti infectives'}
# 230602  {'vitamins minerals nutrients'}
# 230603                  {'respiratory'}
# 230604              {'anti infectives'}
# 230605               {'anti malarials'}
#
#                                          action_class
# 0                                               {nan}
# 1                                               {nan}
# 2          {'h1 antihistaminics (second generation)'}
# 3                                               {nan}
# 4          {'h1 antihistaminics (second generation)'}
# ...                                               ...
# 230601             {'cephalosporins: 2nd generation'}
# 230602                                          {nan}
# 230603      {'h1 antihistaminics (first generation)'}
# 230604                              {'oxazolidinone'}
# 230605  {'antimalarial- artemisinin and derivatives'}
#
# [230606 rows x 7 columns]

# %% [markdown]
# # Bipartite Network

# %%
# Explode the side effects column
df_medications = df_medications.explode(column='side_effects')

# Create a DataFrame only for medications
df_meds = df_medications \
    .drop(columns='side_effects') \
    .rename(columns={'name': 'id'}) \
    .drop_duplicates()
df_meds['label'] = df_meds['id']
df_meds['type'] = 'medication'

# Create a DataFrame only for side effects
df_effects = df_medications \
    [['side_effects']] \
    .rename(columns={'side_effects': 'id'}) \
    .drop_duplicates()
df_effects['label'] = df_effects['id']
df_effects['type'] = 'side effect'

# Create a DataFrame for the nodes
df_bipatite_nodes = pd.concat(
    objs=[df_meds, df_effects], ignore_index=True
)

# Create a DataFrame for the edges
df_bipatite_edges = df_medications \
    [['name', 'side_effects']] \
    .rename(columns={'name': 'source', 'side_effects': 'target'}) \
    .reset_index(drop=True)

# %%
# Store the DataFrame of bipartite network nodes
df_bipatite_nodes.to_csv(
    '../data/processed/bipartite-network-nodes.csv', index=False
)

# Print the DataFrame of bipartite network nodes
df_bipatite_nodes
# Out:
#                                  id  \
# 0       1 al plus 5mg/120mg capsule
# 1                      1 nvp tablet
# 2                    1-al 10 tablet
# 3                      1-al m syrup
# 4                        1-al syrup
# ...                             ...
# 231655                bone weakness
# 231656          tightness sensation
# 231657              feeling of cold
# 231658                     delusion
# 231659       injection site itching
#
#                                                      uses  \
# 0           {' sneezing and runny nose due to allergies'}
# 1       {'treatment of nausea and vomiting in pregnancy'}
# 2                    {'treatment of allergic conditions'}
# 3       {'treatment of sneezing and runny nose due to ...
# 4                    {'treatment of allergic conditions'}
# ...                                                   ...
# 231655                                                NaN
# 231656                                                NaN
# 231657                                                NaN
# 231658                                                NaN
# 231659                                                NaN
#
#                     chemical_class habit_forming      therapeutic_class  \
# 0                            {nan}        {'no'}        {'respiratory'}
# 1                            {nan}        {'no'}  {'gastro intestinal'}
# 2       {'piperazine derivatives'}        {'no'}        {'respiratory'}
# 3                            {nan}        {'no'}        {'respiratory'}
# 4       {'piperazine derivatives'}        {'no'}        {'respiratory'}
# ...                            ...           ...                    ...
# 231655                         NaN           NaN                    NaN
# 231656                         NaN           NaN                    NaN
# 231657                         NaN           NaN                    NaN
# 231658                         NaN           NaN                    NaN
# 231659                         NaN           NaN                    NaN
#
#                                       action_class  \
# 0                                            {nan}
# 1                                            {nan}
# 2       {'h1 antihistaminics (second generation)'}
# 3                                            {nan}
# 4       {'h1 antihistaminics (second generation)'}
# ...                                            ...
# 231655                                         NaN
# 231656                                         NaN
# 231657                                         NaN
# 231658                                         NaN
# 231659                                         NaN
#
#                               label         type
# 0       1 al plus 5mg/120mg capsule   medication
# 1                      1 nvp tablet   medication
# 2                    1-al 10 tablet   medication
# 3                      1-al m syrup   medication
# 4                        1-al syrup   medication
# ...                             ...          ...
# 231655                bone weakness  side effect
# 231656          tightness sensation  side effect
# 231657              feeling of cold  side effect
# 231658                     delusion  side effect
# 231659       injection site itching  side effect
#
# [231660 rows x 8 columns]

# %%
# Store the DataFrame of bipartite network edges
df_bipatite_edges.to_csv(
    '../data/processed/bipartite-network-edges.csv', index=False
)

# Store the DataFrame of bipartite network edges
df_bipatite_edges
# Out:
#                               source  \
# 0        1 al plus 5mg/120mg capsule
# 1        1 al plus 5mg/120mg capsule
# 2        1 al plus 5mg/120mg capsule
# 3        1 al plus 5mg/120mg capsule
# 4        1 al plus 5mg/120mg capsule
# ...                              ...
# 1506039         α-bert 150 injection
# 1506040         α-bert 150 injection
# 1506041         α-bert 150 injection
# 1506042         α-bert 150 injection
# 1506043         α-bert 150 injection
#
#                                                     target
# 0                                               sleepiness
# 1                                                 headache
# 2                                                 vomiting
# 3                                         dryness in mouth
# 4                                                   nausea
# ...                                                    ...
# 1506039                                           headache
# 1506040                                           vomiting
# 1506041                                             nausea
# 1506042                                     abdominal pain
# 1506043  injection site reactions (pain, swelling, redn...
#
# [1506044 rows x 2 columns]

# %% [markdown]
# # Medication Projection

# %%
# # Determine the set of neighbors for each node
# neighbors = defaultdict(set)
# for _, row in df_bipatite_edges.iterrows():
#    neighbors[row['source']].add(row['target'])

# calculate_jaccard_associations(neighbors)

# %% [markdown]
# # Side Effects Projection

# %%
# # Determine the set of neighbors for each node
# neighbors = defaultdict(set)
# for _, row in df_bipatite_edges.iterrows():
#    neighbors[row['target']].add(row['source'])

# calculate_jaccard_associations(neighbors)
