# %% [markdown]
# # **Data Processing**

# %% [markdown]
# # Import Library

# %%
import pandas as pd

# %%
# DataFrame with data about medications and side effects
df_medications = pd.read_csv('../data/raw/medicine-dataset.csv', low_memory=False)

# Print the original DataFrame
df_medications
# Out:
#             id                                  name  \
# 0            1              augmentin 625 duo tablet
# 1            2                   azithral 500 tablet
# 2            3                      ascoril ls syrup
# 3            4                  allegra 120mg tablet
# 4            5                        avil 25 tablet
# ...        ...                                   ...
# 248213  248214  zestrain 100mg/325mg/250mg tablet mr
# 248214  248215              zoxinace 200mg tablet sr
# 248215  248216                     zivex 25mg tablet
# 248216  248217               zi fast 500mg injection
# 248217  248218             zyvocol 1% dusting powder
#
#                                 substitute0             substitute1  \
# 0            Penciclav 500 mg/125 mg Tablet  Moxikind-CV 625 Tablet
# 1                   Zithrocare 500mg Tablet         Azax 500 Tablet
# 2                           Solvin LS Syrup       Ambrodil-LX Syrup
# 3                              Lcfex Tablet     Etofex 120mg Tablet
# 4                        Eralet 25mg Tablet                     NaN
# ...                                     ...                     ...
# 248213  Aclotec MR 100mg/325mg/250mg Tablet       SAMONEC MR TABLET
# 248214                Algic 200mg Tablet SR  Topnac 200mg Tablet SR
# 248215                  HD Zine 25mg Tablet    Hydrocas 25mg Tablet
# 248216                Zycin 500mg Injection  Aziwok 500mg Injection
# 248217              Canazole Dusting Powder  Clotrex Dusting Powder
#
#                                 substitute2  \
# 0                   Moxiforce-CV 625 Tablet
# 1                           Zady 500 Tablet
# 2                         Zerotuss XP Syrup
# 3                      Nexofex 120mg Tablet
# 4                                       NaN
# ...                                     ...
# 248213  Uniclof 100mg/325mg/250mg Tablet MR
# 248214               Kindac 200mg Tablet SR
# 248215                      Hyzox 25 Tablet
# 248216               Azirow 500mg Injection
# 248217                 AF -C Dusting Powder
#
#                                substitute3  \
# 0                       Fightox 625 Tablet
# 1                    Cazithro 500mg Tablet
# 2                           Capex LS Syrup
# 3                      Fexise 120mg Tablet
# 4                                      NaN
# ...                                    ...
# 248213  Macito 100mg/325mg/250mg Tablet MR
# 248214            Ultranac 200mg Tablet SR
# 248215                   Hydil 25mg Tablet
# 248216             Toracin 500mg Injection
# 248217              Klo-Aid Dusting Powder
#
#                                 substitute4  \
# 0                   Novamox CV 625mg Tablet
# 1                     Trulimax 500mg Tablet
# 2                           Broxum LS Syrup
# 3                      Histafree 120 Tablet
# 4                                       NaN
# ...                                     ...
# 248213  Rumatin 100mg/325mg/250mg Tablet MR
# 248214               Bignac 200mg Tablet SR
# 248215                   Zyzine 25mg Tablet
# 248216               Azymed 500mg Injection
# 248217               Nuforce Dusting Powder
#
#                                               sideEffect0       sideEffect1  \
# 0                                                Vomiting            Nausea
# 1                                                Vomiting            Nausea
# 2                                                  Nausea          Vomiting
# 3                                                Headache        Drowsiness
# 4                                              Sleepiness  Dryness in mouth
# ...                                                   ...               ...
# 248213                                             Nausea          Vomiting
# 248214                                          Dizziness       Indigestion
# 248215                                           Sedation            Nausea
# 248216  Injection site reactions (pain, swelling, redn...          Vomiting
# 248217                                           Blisters      Skin peeling
#
#            sideEffect2  ... sideEffect41  \
# 0             Diarrhea  ...          NaN
# 1       Abdominal pain  ...          NaN
# 2             Diarrhea  ...          NaN
# 3            Dizziness  ...          NaN
# 4                  NaN  ...          NaN
# ...                ...  ...          ...
# 248213       Heartburn  ...          NaN
# 248214          Nausea  ...          NaN
# 248215        Vomiting  ...          NaN
# 248216          Nausea  ...          NaN
# 248217        Swelling  ...          NaN
#
#                                                      use0  \
# 0                       Treatment of Bacterial infections
# 1                       Treatment of Bacterial infections
# 2                           Treatment of Cough with mucus
# 3       Treatment of Sneezing and runny nose due to al...
# 4                        Treatment of Allergic conditions
# ...                                                   ...
# 248213                         Treatment of Muscular pain
# 248214                                        Pain relief
# 248215                               Treatment of Anxiety
# 248216                  Treatment of Bacterial infections
# 248217                Treatment of Fungal skin infections
#
#                                                      use1 use2 use3 use4  \
# 0                                                     NaN  NaN  NaN  NaN
# 1                                                     NaN  NaN  NaN  NaN
# 2                                                     NaN  NaN  NaN  NaN
# 3                        Treatment of Allergic conditions  NaN  NaN  NaN
# 4                                                     NaN  NaN  NaN  NaN
# ...                                                   ...  ...  ...  ...
# 248213                                                NaN  NaN  NaN  NaN
# 248214                                                NaN  NaN  NaN  NaN
# 248215  Treatment of Skin conditions with inflammation...  NaN  NaN  NaN
# 248216                                                NaN  NaN  NaN  NaN
# 248217                                                NaN  NaN  NaN  NaN
#
#                         Chemical Class Habit Forming Therapeutic Class  \
# 0                                  NaN            No   ANTI INFECTIVES
# 1                           Macrolides            No   ANTI INFECTIVES
# 2                                  NaN            No       RESPIRATORY
# 3           Diphenylmethane Derivative            No       RESPIRATORY
# 4                Pyridines Derivatives            No       RESPIRATORY
# ...                                ...           ...               ...
# 248213                             NaN            No   PAIN ANALGESICS
# 248214     Dichlorobenzenes Derivative            No   PAIN ANALGESICS
# 248215           Piperazine Derivative            No       RESPIRATORY
# 248216                      Macrolides            No   ANTI INFECTIVES
# 248217  Azole derivatives {Imidazoles}            No             DERMA
#
#                                              Action Class
# 0                                                     NaN
# 1                                              Macrolides
# 2                                                     NaN
# 3                  H1 Antihistaminics (second Generation)
# 4                   H1 Antihistaminics (First Generation)
# ...                                                   ...
# 248213                                                NaN
# 248214  NSAID's- Non-Selective COX 1&2 Inhibitors (ace...
# 248215              H1 Antihistaminics (First Generation)
# 248216                                         Macrolides
# 248217              Fungal ergosterol synthesis inhibitor
#
# [248218 rows x 58 columns]

# %%
# Standardize column names
renamed_cols = dict()
for col in df_medications.columns:
    renamed_cols[col] = col.lower().replace(' ', '_')

# Convert columns values to lowercase
df_medications = df_medications \
    .applymap(lambda x: x.lower() if isinstance(x, str) else x)

# Remove the id column, rename columns, and remove duplicated rows
df_medications = df_medications \
    .drop(columns=['id']) \
    .rename(columns=renamed_cols) \
    .drop_duplicates()

# %%
# Columns of interest for the processed DataFrame
cols_of_interest = [
    col for col in df_medications.columns \
    if (not col.startswith('substitute') and col != 'name')
]

# Columns to iterate over (substitute medications)
cols_to_iterate = [
    col for col in df_medications.columns if col.startswith('substitute')
]

# Create a DataFrame to store the processed data
df_processed_medications = df_medications.copy() \
    .drop(columns=cols_to_iterate)

# Iterate over the substitute columns
for col in cols_to_iterate:
    # Cut the DataFrame according to the column in question
    cols_to_keep = [col] + cols_of_interest
    df_cut = df_medications[cols_to_keep].copy() \
        .rename(columns={col: 'name'}) \
        .dropna(subset='name') \
        .drop_duplicates()
    
    # Concat the data in the processed DataFrame
    df_processed_medications = pd.concat(
        objs=[df_processed_medications, df_cut],
        ignore_index=True
    )

# Remove duplicated rows
df_processed_medications = df_processed_medications.drop_duplicates()

# %%
# Combine the side effects of each row into one list
effect_cols = [col for col in df_processed_medications.columns if col.startswith('sideeffect')]
df_processed_medications['side_effects'] = df_processed_medications[effect_cols] \
    .apply(
        lambda row: sorted(
            [x for x in row.dropna().tolist() if str(x).strip() != '']
        ),
        axis=1
    )
df_processed_medications = df_processed_medications.drop(columns=effect_cols)

# Combine the uses of each row into one list
use_cols = [col for col in df_processed_medications.columns if col.startswith('use')]
df_processed_medications['uses'] = df_processed_medications[use_cols] \
    .apply(
        lambda row: sorted(
            [x for x in row.dropna().tolist() if str(x).strip() != '']
        ),
        axis=1
    )
df_processed_medications = df_processed_medications.drop(columns=use_cols)

# %%
df_processed_medications.sort_values(by='name').reset_index(drop=True)
# Out:
#                                name  \
# 0       1 al plus 5mg/120mg capsule
# 1                      1 nvp tablet
# 2                    1-al 10 tablet
# 3                      1-al m syrup
# 4                        1-al syrup
# ...                             ...
# 231014          zyxtil 500mg tablet
# 231015                  zyzer syrup
# 231016           zyzine 25mg tablet
# 231017        zyzolide 600mg tablet
# 231018         α-bert 150 injection
#
#                                            chemical_class habit_forming  \
# 0                                                     NaN            no
# 1                                                     NaN            no
# 2                                  piperazine derivatives            no
# 3                                                     NaN            no
# 4                                  piperazine derivatives            no
# ...                                                   ...           ...
# 231014  intermediate spectrum {second generation cepha...            no
# 231015                                                NaN            no
# 231016                              piperazine derivative            no
# 231017                           oxazolidinone derivative            no
# 231018                             sesquiterpene lactones            no
#
#                   therapeutic_class  \
# 0                       respiratory
# 1                 gastro intestinal
# 2                       respiratory
# 3                       respiratory
# 4                       respiratory
# ...                             ...
# 231014              anti infectives
# 231015  vitamins minerals nutrients
# 231016                  respiratory
# 231017              anti infectives
# 231018               anti malarials
#
#                                      action_class  \
# 0                                             NaN
# 1                                             NaN
# 2          h1 antihistaminics (second generation)
# 3                                             NaN
# 4          h1 antihistaminics (second generation)
# ...                                           ...
# 231014             cephalosporins: 2nd generation
# 231015                                        NaN
# 231016      h1 antihistaminics (first generation)
# 231017                              oxazolidinone
# 231018  antimalarial- artemisinin and derivatives
#
#                                              side_effects  \
# 0       [dryness in mouth, headache, nausea, restlessn...
# 1       [constipation, dizziness, dryness in mouth, fa...
# 2       [dryness in mouth, fatigue, headache, nasophar...
# 3       [diarrhea, dryness in mouth, fatigue, headache...
# 4       [constipation, dizziness, dryness in mouth, fa...
# ...                                                   ...
# 231014  [allergic reaction, diarrhea, increased liver ...
# 231015  [blurred vision, constipation, drowsiness, dry...
# 231016  [constipation, nausea, sedation, upset stomach...
# 231017  [decreased blood cells (red cells, white cells...
# 231018  [abdominal pain, headache, injection site reac...
#
#                                                      uses
# 0             [ sneezing and runny nose due to allergies]
# 1         [treatment of nausea and vomiting in pregnancy]
# 2                      [treatment of allergic conditions]
# 3       [treatment of allergic skin conditions, treatm...
# 4                      [treatment of allergic conditions]
# ...                                                   ...
# 231014                [treatment of bacterial infections]
# 231015                              [ appetite stimulant]
# 231016  [treatment of anxiety, treatment of skin condi...
# 231017         [treatment of severe bacterial infections]
# 231018                                         [ malaria]
#
# [231019 rows x 7 columns]

# %%
df_processed_medications
# Out:
#                                  name  \
# 0            augmentin 625 duo tablet
# 1                 azithral 500 tablet
# 2                    ascoril ls syrup
# 3                allegra 120mg tablet
# 4                      avil 25 tablet
# ...                               ...
# 298598          simzopox 400mg tablet
# 298609                 pisi injection
# 298613  fevedot 125mg oral suspension
# 298615        acizide 125mg injection
# 298617          setnther-ab injection
#
#                                            chemical_class habit_forming  \
# 0                                                     NaN            no
# 1                                              macrolides            no
# 2                                                     NaN            no
# 3                              diphenylmethane derivative            no
# 4                                   pyridines derivatives            no
# ...                                                   ...           ...
# 298598                                  nucleoside analog            no
# 298609                            enolic acid derivatives            no
# 298613                           p-aminophenol derivative            no
# 298615  broad spectrum (third & fourth generation ceph...            no
# 298617                             sesquiterpene lactones            no
#
#        therapeutic_class                                       action_class  \
# 0        anti infectives                                                NaN
# 1        anti infectives                                         macrolides
# 2            respiratory                                                NaN
# 3            respiratory             h1 antihistaminics (second generation)
# 4            respiratory              h1 antihistaminics (first generation)
# ...                  ...                                                ...
# 298598   anti infectives                          antiviral (non-hiv) drugs
# 298609   pain analgesics  nsaid's- non-selective cox 1&2 inhibitors (eno...
# 298613   pain analgesics                        analgesic & antipyretic-pcm
# 298615   anti infectives                       cephalosporins: 3 generation
# 298617    anti malarials          antimalarial- artemisinin and derivatives
#
#                                              side_effects  \
# 0                            [diarrhea, nausea, vomiting]
# 1            [abdominal pain, diarrhea, nausea, vomiting]
# 2       [allergic reaction, diarrhea, dizziness, heada...
# 3               [dizziness, drowsiness, headache, nausea]
# 4                          [dryness in mouth, sleepiness]
# ...                                                   ...
# 298598  [diarrhea, dizziness, fatigue, fever, headache...
# 298609  [dizziness, headache, injection site reactions...
# 298613      [indigestion, nausea, stomach pain, vomiting]
# 298615  [allergic reaction, diarrhea, injection site r...
# 298617  [abdominal pain, headache, injection site reac...
#
#                                                      uses
# 0                     [treatment of bacterial infections]
# 1                     [treatment of bacterial infections]
# 2                         [treatment of cough with mucus]
# 3       [treatment of allergic conditions, treatment o...
# 4                      [treatment of allergic conditions]
# ...                                                   ...
# 298598  [ chickenpox,  genital herpes infection,  herp...
# 298609                                     [ pain relief]
# 298613                 [ pain relief, treatment of fever]
# 298615                            [ bacterial infections]
# 298617                                         [ malaria]
#
# [231019 rows x 7 columns]

# %%
df_processed_medications.explode(column='side_effects')
# Out:
#                             name          chemical_class habit_forming  \
# 0       augmentin 625 duo tablet                     NaN            no
# 0       augmentin 625 duo tablet                     NaN            no
# 0       augmentin 625 duo tablet                     NaN            no
# 1            azithral 500 tablet              macrolides            no
# 1            azithral 500 tablet              macrolides            no
# ...                          ...                     ...           ...
# 298617     setnther-ab injection  sesquiterpene lactones            no
# 298617     setnther-ab injection  sesquiterpene lactones            no
# 298617     setnther-ab injection  sesquiterpene lactones            no
# 298617     setnther-ab injection  sesquiterpene lactones            no
# 298617     setnther-ab injection  sesquiterpene lactones            no
#
#        therapeutic_class                               action_class  \
# 0        anti infectives                                        NaN
# 0        anti infectives                                        NaN
# 0        anti infectives                                        NaN
# 1        anti infectives                                 macrolides
# 1        anti infectives                                 macrolides
# ...                  ...                                        ...
# 298617    anti malarials  antimalarial- artemisinin and derivatives
# 298617    anti malarials  antimalarial- artemisinin and derivatives
# 298617    anti malarials  antimalarial- artemisinin and derivatives
# 298617    anti malarials  antimalarial- artemisinin and derivatives
# 298617    anti malarials  antimalarial- artemisinin and derivatives
#
#                                              side_effects  \
# 0                                                diarrhea
# 0                                                  nausea
# 0                                                vomiting
# 1                                          abdominal pain
# 1                                                diarrhea
# ...                                                   ...
# 298617                                     abdominal pain
# 298617                                           headache
# 298617  injection site reactions (pain, swelling, redn...
# 298617                                             nausea
# 298617                                           vomiting
#
#                                        uses
# 0       [treatment of bacterial infections]
# 0       [treatment of bacterial infections]
# 0       [treatment of bacterial infections]
# 1       [treatment of bacterial infections]
# 1       [treatment of bacterial infections]
# ...                                     ...
# 298617                           [ malaria]
# 298617                           [ malaria]
# 298617                           [ malaria]
# 298617                           [ malaria]
# 298617                           [ malaria]
#
# [1507444 rows x 7 columns]

# %%
df_processed_medications.explode(column='uses')
# Out:
#                                  name  \
# 0            augmentin 625 duo tablet
# 1                 azithral 500 tablet
# 2                    ascoril ls syrup
# 3                allegra 120mg tablet
# 3                allegra 120mg tablet
# ...                               ...
# 298609                 pisi injection
# 298613  fevedot 125mg oral suspension
# 298613  fevedot 125mg oral suspension
# 298615        acizide 125mg injection
# 298617          setnther-ab injection
#
#                                            chemical_class habit_forming  \
# 0                                                     NaN            no
# 1                                              macrolides            no
# 2                                                     NaN            no
# 3                              diphenylmethane derivative            no
# 3                              diphenylmethane derivative            no
# ...                                                   ...           ...
# 298609                            enolic acid derivatives            no
# 298613                           p-aminophenol derivative            no
# 298613                           p-aminophenol derivative            no
# 298615  broad spectrum (third & fourth generation ceph...            no
# 298617                             sesquiterpene lactones            no
#
#        therapeutic_class                                       action_class  \
# 0        anti infectives                                                NaN
# 1        anti infectives                                         macrolides
# 2            respiratory                                                NaN
# 3            respiratory             h1 antihistaminics (second generation)
# 3            respiratory             h1 antihistaminics (second generation)
# ...                  ...                                                ...
# 298609   pain analgesics  nsaid's- non-selective cox 1&2 inhibitors (eno...
# 298613   pain analgesics                        analgesic & antipyretic-pcm
# 298613   pain analgesics                        analgesic & antipyretic-pcm
# 298615   anti infectives                       cephalosporins: 3 generation
# 298617    anti malarials          antimalarial- artemisinin and derivatives
#
#                                              side_effects  \
# 0                            [diarrhea, nausea, vomiting]
# 1            [abdominal pain, diarrhea, nausea, vomiting]
# 2       [allergic reaction, diarrhea, dizziness, heada...
# 3               [dizziness, drowsiness, headache, nausea]
# 3               [dizziness, drowsiness, headache, nausea]
# ...                                                   ...
# 298609  [dizziness, headache, injection site reactions...
# 298613      [indigestion, nausea, stomach pain, vomiting]
# 298613      [indigestion, nausea, stomach pain, vomiting]
# 298615  [allergic reaction, diarrhea, injection site r...
# 298617  [abdominal pain, headache, injection site reac...
#
#                                                      uses
# 0                       treatment of bacterial infections
# 1                       treatment of bacterial infections
# 2                           treatment of cough with mucus
# 3                        treatment of allergic conditions
# 3       treatment of sneezing and runny nose due to al...
# ...                                                   ...
# 298609                                        pain relief
# 298613                                        pain relief
# 298613                                 treatment of fever
# 298615                               bacterial infections
# 298617                                            malaria
#
# [337924 rows x 7 columns]
