# %% [markdown]
# # **Exploratory Data Analysis of the Dataset**
# Kaggle Dataset: [250k Medicines Usage, Side Effects and Substitutes](https://www.kaggle.com/datasets/shudhanshusingh/250k-medicines-usage-side-effects-and-substitutes)

# %% [markdown]
# # Import Library

# %%
import pandas as pd

# %% [markdown]
# # Load the Dataset

# %%
# DataFrame with data about medications and side effects
df_medications = pd.read_csv('../data/raw/medicine-dataset.csv', low_memory=False)

# Print the original DataFrame
df_medications
# Out:
#             id                                  name  \
# 0            1              augmentin 625 duo tablet
# 1            2                   azithral 500 tablet
# 2            3                      ascoril ls syrup
# 3            4                  allegra 120mg tablet
# 4            5                        avil 25 tablet
# ...        ...                                   ...
# 248213  248214  zestrain 100mg/325mg/250mg tablet mr
# 248214  248215              zoxinace 200mg tablet sr
# 248215  248216                     zivex 25mg tablet
# 248216  248217               zi fast 500mg injection
# 248217  248218             zyvocol 1% dusting powder
#
#                                 substitute0             substitute1  \
# 0            Penciclav 500 mg/125 mg Tablet  Moxikind-CV 625 Tablet
# 1                   Zithrocare 500mg Tablet         Azax 500 Tablet
# 2                           Solvin LS Syrup       Ambrodil-LX Syrup
# 3                              Lcfex Tablet     Etofex 120mg Tablet
# 4                        Eralet 25mg Tablet                     NaN
# ...                                     ...                     ...
# 248213  Aclotec MR 100mg/325mg/250mg Tablet       SAMONEC MR TABLET
# 248214                Algic 200mg Tablet SR  Topnac 200mg Tablet SR
# 248215                  HD Zine 25mg Tablet    Hydrocas 25mg Tablet
# 248216                Zycin 500mg Injection  Aziwok 500mg Injection
# 248217              Canazole Dusting Powder  Clotrex Dusting Powder
#
#                                 substitute2  \
# 0                   Moxiforce-CV 625 Tablet
# 1                           Zady 500 Tablet
# 2                         Zerotuss XP Syrup
# 3                      Nexofex 120mg Tablet
# 4                                       NaN
# ...                                     ...
# 248213  Uniclof 100mg/325mg/250mg Tablet MR
# 248214               Kindac 200mg Tablet SR
# 248215                      Hyzox 25 Tablet
# 248216               Azirow 500mg Injection
# 248217                 AF -C Dusting Powder
#
#                                substitute3  \
# 0                       Fightox 625 Tablet
# 1                    Cazithro 500mg Tablet
# 2                           Capex LS Syrup
# 3                      Fexise 120mg Tablet
# 4                                      NaN
# ...                                    ...
# 248213  Macito 100mg/325mg/250mg Tablet MR
# 248214            Ultranac 200mg Tablet SR
# 248215                   Hydil 25mg Tablet
# 248216             Toracin 500mg Injection
# 248217              Klo-Aid Dusting Powder
#
#                                 substitute4  \
# 0                   Novamox CV 625mg Tablet
# 1                     Trulimax 500mg Tablet
# 2                           Broxum LS Syrup
# 3                      Histafree 120 Tablet
# 4                                       NaN
# ...                                     ...
# 248213  Rumatin 100mg/325mg/250mg Tablet MR
# 248214               Bignac 200mg Tablet SR
# 248215                   Zyzine 25mg Tablet
# 248216               Azymed 500mg Injection
# 248217               Nuforce Dusting Powder
#
#                                               sideEffect0       sideEffect1  \
# 0                                                Vomiting            Nausea
# 1                                                Vomiting            Nausea
# 2                                                  Nausea          Vomiting
# 3                                                Headache        Drowsiness
# 4                                              Sleepiness  Dryness in mouth
# ...                                                   ...               ...
# 248213                                             Nausea          Vomiting
# 248214                                          Dizziness       Indigestion
# 248215                                           Sedation            Nausea
# 248216  Injection site reactions (pain, swelling, redn...          Vomiting
# 248217                                           Blisters      Skin peeling
#
#            sideEffect2  ... sideEffect41  \
# 0             Diarrhea  ...          NaN
# 1       Abdominal pain  ...          NaN
# 2             Diarrhea  ...          NaN
# 3            Dizziness  ...          NaN
# 4                  NaN  ...          NaN
# ...                ...  ...          ...
# 248213       Heartburn  ...          NaN
# 248214          Nausea  ...          NaN
# 248215        Vomiting  ...          NaN
# 248216          Nausea  ...          NaN
# 248217        Swelling  ...          NaN
#
#                                                      use0  \
# 0                       Treatment of Bacterial infections
# 1                       Treatment of Bacterial infections
# 2                           Treatment of Cough with mucus
# 3       Treatment of Sneezing and runny nose due to al...
# 4                        Treatment of Allergic conditions
# ...                                                   ...
# 248213                         Treatment of Muscular pain
# 248214                                        Pain relief
# 248215                               Treatment of Anxiety
# 248216                  Treatment of Bacterial infections
# 248217                Treatment of Fungal skin infections
#
#                                                      use1 use2 use3 use4  \
# 0                                                     NaN  NaN  NaN  NaN
# 1                                                     NaN  NaN  NaN  NaN
# 2                                                     NaN  NaN  NaN  NaN
# 3                        Treatment of Allergic conditions  NaN  NaN  NaN
# 4                                                     NaN  NaN  NaN  NaN
# ...                                                   ...  ...  ...  ...
# 248213                                                NaN  NaN  NaN  NaN
# 248214                                                NaN  NaN  NaN  NaN
# 248215  Treatment of Skin conditions with inflammation...  NaN  NaN  NaN
# 248216                                                NaN  NaN  NaN  NaN
# 248217                                                NaN  NaN  NaN  NaN
#
#                         Chemical Class Habit Forming Therapeutic Class  \
# 0                                  NaN            No   ANTI INFECTIVES
# 1                           Macrolides            No   ANTI INFECTIVES
# 2                                  NaN            No       RESPIRATORY
# 3           Diphenylmethane Derivative            No       RESPIRATORY
# 4                Pyridines Derivatives            No       RESPIRATORY
# ...                                ...           ...               ...
# 248213                             NaN            No   PAIN ANALGESICS
# 248214     Dichlorobenzenes Derivative            No   PAIN ANALGESICS
# 248215           Piperazine Derivative            No       RESPIRATORY
# 248216                      Macrolides            No   ANTI INFECTIVES
# 248217  Azole derivatives {Imidazoles}            No             DERMA
#
#                                              Action Class
# 0                                                     NaN
# 1                                              Macrolides
# 2                                                     NaN
# 3                  H1 Antihistaminics (second Generation)
# 4                   H1 Antihistaminics (First Generation)
# ...                                                   ...
# 248213                                                NaN
# 248214  NSAID's- Non-Selective COX 1&2 Inhibitors (ace...
# 248215              H1 Antihistaminics (First Generation)
# 248216                                         Macrolides
# 248217              Fungal ergosterol synthesis inhibitor
#
# [248218 rows x 58 columns]

# %% [markdown]
# # Investigation of All Records

# %%
# Print the DataFrame summary
df_medications.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248218 entries, 0 to 248217
# Data columns (total 58 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 248218 non-null  int64
#  1   name               248218 non-null  object
#  2   substitute0        238621 non-null  object
#  3   substitute1        233867 non-null  object
#  4   substitute2        230233 non-null  object
#  5   substitute3        226856 non-null  object
#  6   substitute4        223962 non-null  object
#  7   sideEffect0        248218 non-null  object
#  8   sideEffect1        238416 non-null  object
#  9   sideEffect2        229500 non-null  object
#  10  sideEffect3        207638 non-null  object
#  11  sideEffect4        163560 non-null  object
#  12  sideEffect5        131258 non-null  object
#  13  sideEffect6        91857 non-null   object
#  14  sideEffect7        67750 non-null   object
#  15  sideEffect8        48506 non-null   object
#  16  sideEffect9        37708 non-null   object
#  17  sideEffect10       27274 non-null   object
#  18  sideEffect11       20331 non-null   object
#  19  sideEffect12       16282 non-null   object
#  20  sideEffect13       14727 non-null   object
#  21  sideEffect14       10419 non-null   object
#  22  sideEffect15       7681 non-null    object
#  23  sideEffect16       6009 non-null    object
#  24  sideEffect17       5382 non-null    object
#  25  sideEffect18       4515 non-null    object
#  26  sideEffect19       3946 non-null    object
#  27  sideEffect20       3223 non-null    object
#  28  sideEffect21       3125 non-null    object
#  29  sideEffect22       3048 non-null    object
#  30  sideEffect23       2905 non-null    object
#  31  sideEffect24       2723 non-null    object
#  32  sideEffect25       1503 non-null    object
#  33  sideEffect26       1503 non-null    object
#  34  sideEffect27       1494 non-null    object
#  35  sideEffect28       1494 non-null    object
#  36  sideEffect29       1438 non-null    object
#  37  sideEffect30       1329 non-null    object
#  38  sideEffect31       1329 non-null    object
#  39  sideEffect32       1328 non-null    object
#  40  sideEffect33       1169 non-null    object
#  41  sideEffect34       1166 non-null    object
#  42  sideEffect35       2 non-null       object
#  43  sideEffect36       2 non-null       object
#  44  sideEffect37       2 non-null       object
#  45  sideEffect38       2 non-null       object
#  46  sideEffect39       2 non-null       object
#  47  sideEffect40       2 non-null       object
#  48  sideEffect41       2 non-null       object
#  49  use0               248218 non-null  object
#  50  use1               73365 non-null   object
#  51  use2               28307 non-null   object
#  52  use3               7379 non-null    object
#  53  use4               4971 non-null    object
#  54  Chemical Class     137791 non-null  object
#  55  Habit Forming      248218 non-null  object
#  56  Therapeutic Class  248149 non-null  object
#  57  Action Class       138036 non-null  object
# dtypes: int64(1), object(57)
# memory usage: 109.8+ MB

# %%
# Total of records in the dataset
df_medications.shape[0]
# Out:
# 248218

# %%
# Total of records without total repetition in the dataset
df_medications.drop(columns=['id']).drop_duplicates().shape[0]
# Out:
# 224014

# %% [markdown]
# # Investigation of the Columns
# With the removal of the `id` column

# %%
# Remove the id column and the records with all duplicate columns
df_medications = df_medications.drop(columns=['id']).drop_duplicates()

# %% [markdown]
# ## `name`

# %%
# Create the set of names
all_names = set(df_medications['name'].to_list())

# Total of unique names
print(len(all_names))
# Out:
# 222825

# %%
# Names with more than one associated record
df_medications['name'] \
    .value_counts() \
    .reset_index() \
    .query('count > 1')
# Out:
#                             name  count
# 0        ringer lactate infusion      4
# 1             cefpoxim dry syrup      4
# 2            azicon 500mg tablet      3
# 3             loxin 500mg tablet      3
# 4              kidivent-ls syrup      3
# ...                          ...    ...
# 1160  fycare-d 30mg/20mg capsule      2
# 1161          mytrip 25mg tablet      2
# 1162             amcard 5 tablet      2
# 1163       weldec 50mg injection      2
# 1164               cypotin syrup      2
#
# [1165 rows x 2 columns]

# %%
# Example of name with "repeated" records [1]
df_medications.query('name == "ringer lactate infusion"')
# Out:
#                            name              substitute0  \
# 199320  ringer lactate infusion  Ringer Lactate Infusion
# 201811  ringer lactate infusion  Ringer Lactate Infusion
# 202568  ringer lactate infusion  Ringer Lactate Infusion
# 203065  ringer lactate infusion                      NaN
#
#                             substitute1                      substitute2  \
# 199320  Ringer Lactate IP Poly Infusion                      RL Infusion
# 201811          Ringer Lactate Infusion  Ringer Lactate IP Poly Infusion
# 202568          RINGER LACTATE INFUSION          RINGER LACTATE INFUSION
# 203065                              NaN                              NaN
#
#                     substitute3 substitute4                  sideEffect0  \
# 199320  Ringer Lactate Infusion         NaN  No common side effects seen
# 201811              RL Infusion         NaN  No common side effects seen
# 202568                      NaN         NaN  No common side effects seen
# 203065                      NaN         NaN  No common side effects seen
#
#        sideEffect1 sideEffect2 sideEffect3  ... sideEffect41  \
# 199320         NaN         NaN         NaN  ...          NaN
# 201811         NaN         NaN         NaN  ...          NaN
# 202568         NaN         NaN         NaN  ...          NaN
# 203065         NaN         NaN         NaN  ...          NaN
#
#                                               use0 use1 use2 use3 use4  \
# 199320   Short term fluid replacement after trauma  NaN  NaN  NaN  NaN
# 201811   Short term fluid replacement after trauma  NaN  NaN  NaN  NaN
# 202568   Short term fluid replacement after trauma  NaN  NaN  NaN  NaN
# 203065   Short term fluid replacement after trauma  NaN  NaN  NaN  NaN
#
#        Chemical Class Habit Forming Therapeutic Class Action Class
# 199320            NaN            No     BLOOD RELATED          NaN
# 201811            NaN            No     BLOOD RELATED          NaN
# 202568            NaN            No     BLOOD RELATED          NaN
# 203065            NaN            No     BLOOD RELATED          NaN
#
# [4 rows x 57 columns]

# %%
# Example of name with "repeated" records [2]
df_medications.query('name == "cefpoxim dry syrup"')
# Out:
#                      name                     substitute0  \
# 56617  cefpoxim dry syrup  Glapod 50 Dry Syrup Strawberry
# 61997  cefpoxim dry syrup                Qc Pod Dry Syrup
# 64200  cefpoxim dry syrup     Cemcin 50mg Oral Suspension
# 65931  cefpoxim dry syrup                Qc Pod Dry Syrup
#
#                              substitute1           substitute2  \
# 56617        Cemcin 50mg Oral Suspension  Cefudox-DS Dry Syrup
# 61997  Actipod 50 Dry Syrup Orange-Lemon    Podef-DS Dry Syrup
# 64200               Cefudox-DS Dry Syrup   Emidox 50 Dry Syrup
# 65931  Actipod 50 Dry Syrup Orange-Lemon    Podef-DS Dry Syrup
#
#                  substitute3           substitute4     sideEffect0  \
# 56617    Emidox 50 Dry Syrup       Ogpod Dry Syrup  Abdominal pain
# 61997   Tilpod 100 Dry Syrup  Jadupox-DS Dry Syrup            Rash
# 64200  Cefpovec 50 Dry Syrup      Vakcef Dry Syrup  Abdominal pain
# 65931   Jadupox-DS Dry Syrup  Tilpod 100 Dry Syrup            Rash
#
#       sideEffect1 sideEffect2 sideEffect3  ... sideEffect41  \
# 56617        Rash      Nausea    Diarrhea  ...          NaN
# 61997      Nausea    Diarrhea         NaN  ...          NaN
# 64200        Rash      Nausea    Diarrhea  ...          NaN
# 65931      Nausea    Diarrhea         NaN  ...          NaN
#
#                                     use0 use1 use2 use3 use4  \
# 56617  Treatment of Bacterial infections  NaN  NaN  NaN  NaN
# 61997  Treatment of Bacterial infections  NaN  NaN  NaN  NaN
# 64200  Treatment of Bacterial infections  NaN  NaN  NaN  NaN
# 65931  Treatment of Bacterial infections  NaN  NaN  NaN  NaN
#
#                                           Chemical Class Habit Forming  \
# 56617  Broad Spectrum (Third & fourth generation ceph...            No
# 61997  Broad Spectrum (Third & fourth generation ceph...            No
# 64200  Broad Spectrum (Third & fourth generation ceph...            No
# 65931  Broad Spectrum (Third & fourth generation ceph...            No
#
#       Therapeutic Class                  Action Class
# 56617   ANTI INFECTIVES  Cephalosporins: 3 generation
# 61997   ANTI INFECTIVES  Cephalosporins: 3 generation
# 64200   ANTI INFECTIVES  Cephalosporins: 3 generation
# 65931   ANTI INFECTIVES  Cephalosporins: 3 generation
#
# [4 rows x 57 columns]

# %%
# Example of name with "repeated" records [3]
df_medications.query('name == "azicon 500mg tablet"')
# Out:
#                       name              substitute0      substitute1  \
# 4505   azicon 500mg tablet  Zithrocare 500mg Tablet  Azax 500 Tablet
# 8606   azicon 500mg tablet          Azax 500 Tablet  Zady 500 Tablet
# 14552  azicon 500mg tablet          Azax 500 Tablet  Zady 500 Tablet
#
#                  substitute2            substitute3         substitute4  \
# 4505         Zady 500 Tablet  Trulimax 500mg Tablet  Azifast 500 Tablet
# 8606   Trulimax 500mg Tablet     Azifast 500 Tablet  Zithrox 500 Tablet
# 14552    Aziliz 500mg Tablet  Trulimax 500mg Tablet  Azifast 500 Tablet
#
#       sideEffect0 sideEffect1     sideEffect2 sideEffect3  ... sideEffect41  \
# 4505     Vomiting      Nausea  Abdominal pain    Diarrhea  ...          NaN
# 8606     Vomiting      Nausea  Abdominal pain    Diarrhea  ...          NaN
# 14552    Vomiting      Nausea  Abdominal pain    Diarrhea  ...          NaN
#
#                                     use0 use1 use2 use3 use4 Chemical Class  \
# 4505   Treatment of Bacterial infections  NaN  NaN  NaN  NaN     Macrolides
# 8606   Treatment of Bacterial infections  NaN  NaN  NaN  NaN     Macrolides
# 14552  Treatment of Bacterial infections  NaN  NaN  NaN  NaN     Macrolides
#
#       Habit Forming Therapeutic Class Action Class
# 4505             No   ANTI INFECTIVES   Macrolides
# 8606             No   ANTI INFECTIVES   Macrolides
# 14552            No   ANTI INFECTIVES   Macrolides
#
# [3 rows x 57 columns]

# %% [markdown]
# ## `substitute0` to `substitute4`

# %%
# Create a set to store the substitutes
all_substitutes = set()

# Iterate over each substitute column
for i in range(0, 5):
    # Set the target column
    column_name = f'substitute{i}'
    
    # Create a list of unique substitutes
    substitutes = df_medications[column_name] \
        .dropna() \
        .drop_duplicates() \
        .to_list()

    # Add the column to the list
    all_substitutes.update(substitutes)

# Total of unique substitutes
print(len(all_substitutes))
# Out:
# 46684

# %%
# Intersection between names and substitutes
all_names.intersection(all_substitutes)
# Out:
# set()

# %%
# Total of medications
print(len(all_names) + len(all_substitutes))
# Out:
# 269509

# %% [markdown]
# ## `sideEffect0` to `sideEffect41`

# %%
# Create a DataFrame to store the frequency of each side effect
df_all_side_effects_count = pd.DataFrame()

# Iterate over each side effect column
for i in range(0, 42):
    # Set the target column
    column_name = f'sideEffect{i}'
    
    # Quantify the frequency of the side effects in the column
    df_side_effects_count = df_medications[column_name] \
        .value_counts() \
        .reset_index() \
        .rename(columns={column_name: 'sideEffect'})

    # Concatenate the side effects frequency with the others
    df_all_side_effects_count = \
        pd.concat([df_all_side_effects_count, df_side_effects_count])

# Aggregate the side effects and sum their frequencies
df_all_side_effects_count = df_all_side_effects_count \
    .groupby('sideEffect') \
    .agg(count = pd.NamedAgg(column='count', aggfunc='sum')) \
    .sort_values(by='count', ascending=False) \
    .reset_index()

# %%
# Total of unique side effects
df_all_side_effects_count.shape[0]
# Out:
# 1054

# %%
# Most recurrent side effects
df_all_side_effects_count.head(10)
# Out:
#          sideEffect   count
# 0            Nausea  141662
# 1          Diarrhea  125525
# 2          Vomiting   90349
# 3          Headache   90044
# 4         Dizziness   66296
# 5      Stomach pain   45725
# 6              Rash   31780
# 7  Dryness in mouth   31208
# 8        Sleepiness   30745
# 9        Flatulence   28918

# %% [markdown]
# ## `use0` to `use4`

# %%
# Create a DataFrame to store the frequency of each use
df_all_uses_count = pd.DataFrame()

# Iterate over each use column
for i in range(0, 5):
    # Set the target column
    column_name = f'use{i}'
    
    # Quantify the frequency of the uses in the column
    df_uses_count = df_medications[column_name] \
        .value_counts() \
        .reset_index() \
        .rename(columns={column_name: 'use'})

    # Concatenate the uses frequency with the others
    df_all_uses_count = pd.concat([df_all_uses_count, df_uses_count])
46
# Aggregate the uses and sum their frequencies
df_all_uses_count = df_all_uses_count \
    .groupby('use') \
    .agg(count = pd.NamedAgg(column='count', aggfunc='sum')) \
    .sort_values(by='count', ascending=False) \
    .reset_index()

# %%
# Total of unique uses
df_all_uses_count.shape[0]
# Out:
# 819

# %%
# Most recurrent uses
df_all_uses_count.head(10)
# Out:
#                                                  use  count
# 0                  Treatment of Bacterial infections  37129
# 1                                        Pain relief  21152
# 2                  Treatment of Peptic ulcer disease  12581
# 3  Treatment of Gastroesophageal reflux disease (...  12556
# 4              Treatment of Type 2 diabetes mellitus  10250
# 5                               Bacterial infections   9719
# 6    Treatment of Hypertension (high blood pressure)   7178
# 7                   Treatment of Allergic conditions   5766
# 8  Treatment of Sneezing and runny nose due to al...   4904
# 9                             Treatment of Heartburn   4381

# %% [markdown]
# ## `Habit Forming`

# %%
# Count medications by habit forming characterization
df_medications['Habit Forming'].value_counts().reset_index()
# Out:
#   Habit Forming   count
# 0            No  218553
# 1           Yes    5461

# %%
# Create a DataFrame to store the frequency of each habit forming side effects
df_all_side_effects_count = pd.DataFrame()

# Iterate over each side effect column
for i in range(0, 5):
    # Set the target column
    column_name = f'sideEffect{i}'
    
    # Quantify the frequency of the side effects in the column
    df_side_effects_count = \
        df_medications[df_medications['Habit Forming'] == 'Yes'] \
        [column_name] \
        .value_counts() \
        .reset_index() \
        .rename(columns={column_name: 'sideEffect'})

    # Concatenate the side effects frequency with the others
    df_all_side_effects_count = \
        pd.concat([df_all_side_effects_count, df_side_effects_count])

# Most recurrent habit forming side effects
df_all_side_effects_count \
    .groupby('sideEffect') \
    .agg(count = pd.NamedAgg(column='count', aggfunc='sum')) \
    .sort_values(by='count', ascending=False) \
    .reset_index() \
    .head(10)
# Out:
#           sideEffect  count
# 0          Dizziness   2763
# 1         Drowsiness   2670
# 2           Vomiting   2151
# 3             Nausea   2050
# 4       Constipation   1892
# 5          Confusion   1488
# 6         Sleepiness   1264
# 7  Memory impairment   1184
# 8         Depression    999
# 9            Fatigue    989

# %%
# Create a DataFrame to store the frequency of each habit forming use
df_all_uses_count = pd.DataFrame()

# Iterate over each use column
for i in range(0, 5):
    # Set the target column
    column_name = f'use{i}'
    
    # Quantify the frequency of the uses in the column
    df_uses_count = \
        df_medications[df_medications['Habit Forming'] == 'Yes'] \
        [column_name] \
        .value_counts() \
        .reset_index() \
        .rename(columns={column_name: 'use'})

    # Concatenate the uses frequency with the others
    df_all_uses_count = pd.concat([df_all_uses_count, df_uses_count])

# Most recurrent habit forming uses
df_all_uses_count \
    .groupby('use') \
    .agg(count = pd.NamedAgg(column='count', aggfunc='sum')) \
    .sort_values(by='count', ascending=False) \
    .reset_index() \
    .head(10)
# Out:
#                                use  count
# 0    Treatment of Anxiety disorder   1646
# 1   Treatment of Epilepsy/Seizures    937
# 2          Moderate to severe pain    723
# 3             Treatment of Anxiety    634
# 4      Treatment of Panic disorder    625
# 5                      Pain relief    336
# 6            Treatment of Insomnia    309
# 7                       Depression    267
# 8  Treatment of Short term anxiety    250
# 9          Treatment of Depression    229

# %%
# Frequency of habit forming chemical classes
df_medications[df_medications['Habit Forming'] == 'Yes'] \
    ['Chemical Class'] \
    .value_counts() \
    .reset_index()
# Out:
#                                   Chemical Class  count
# 0                     Benzodiazepines Derivative   2025
# 1                             Anisole Derivative    365
# 2                     Imidazopyridine Derivative    194
# 3                      Benzodiazepine Derivative     83
# 4                     Barbituric Acid Derivative     55
# 5                     Diphenylmethane Derivative     49
# 6                      Cyclopyrrolone Derivative     28
# 7                      Phenanthrenes Derivatives     26
# 8                       Phenanthrenes Derivative     22
# 9                        Aralkylamine Derivative     21
# 10                      Benzomorphan Derivatives     20
# 11                  Phenylpiperidine Derivatives     12
# 12  Ultrashort-Acting Barbituric Acid Derivative     11
# 13                 Pyrazolopyrimidine Derivative     11
# 14                      Amphetamines Derivatives      6
# 15                 Phenylheptylamines Derivative      1

# %%
# Frequency of habit forming therapeutical classes
df_medications[df_medications['Habit Forming'] == 'Yes'] \
    ['Therapeutic Class'] \
    .value_counts() \
    .reset_index()
# Out:
#    Therapeutic Class  count
# 0          NEURO CNS   3676
# 1    PAIN ANALGESICS   1114
# 2        RESPIRATORY    442
# 3  GASTRO INTESTINAL    223
# 4            CARDIAC      6

# %%
# Frequency of habit forming action classes
df_medications[df_medications['Habit Forming'] == 'Yes'] \
    ['Action Class'] \
    .value_counts() \
    .reset_index()
# Out:
#                                  Action Class  count
# 0                             Benzodiazepines   2108
# 1                                     Opioids    420
# 2  Non-benzodiazepine hypnotics (Z Compounds)    233
# 3                                 Barbiturate     66
# 4    Stimulant/ Drug for excessive sleepiness     49
# 5                    Opioids- Partial agonist     26
# 6                     Sympthatomimmetics-ADHD     21
# 7                    Sympathomimetics agonist      6

# %% [markdown]
# ## `Chemical Class`

# %%
# Total of unique chemical classes
df_medications['Chemical Class'].dropna().nunique()
# Out:
# 872

# %%
# Most recurrent chemical classes
df_medications['Chemical Class'].value_counts().reset_index().head(10)
# Out:
#                                       Chemical Class  count
# 0                                    Fluoroquinolone   7007
# 1  Broad Spectrum (Third & fourth generation ceph...   6407
# 2                                         Macrolides   4808
# 3                   Sulfinylbenzimidazole Derivative   4395
# 4  Broad spectrum (Third & fourth generation ceph...   3936
# 5  Gluco/mineralocorticoids, progestogins and der...   2604
# 6                                 Azoles {Triazoles}   2443
# 7  Intermediate spectrum {Second generation cepha...   2375
# 8                               Carbazole Derivative   2278
# 9                                    Glucocorticoids   2238

# %% [markdown]
# ## `Therapeutic Class`

# %%
# Total of unique therapeutic classes
df_medications['Therapeutic Class'].dropna().nunique()
# Out:
# 22

# %%
# Most recurrent therapeutic classes
df_medications['Therapeutic Class'].value_counts().reset_index().head(10)
# Out:
#    Therapeutic Class  count
# 0    ANTI INFECTIVES  50459
# 1  GASTRO INTESTINAL  30442
# 2    PAIN ANALGESICS  29187
# 3          NEURO CNS  21524
# 4        RESPIRATORY  21284
# 5            CARDIAC  16774
# 6      ANTI DIABETIC  10457
# 7            OPHTHAL   9494
# 8              DERMA   8949
# 9           HORMONES   4927

# %% [markdown]
# ## `Action Class`

# %%
# Total of unique action classes
df_medications['Action Class'].dropna().nunique()
# Out:
# 431

# %%
# Most recurrent action classes
df_medications['Action Class'].value_counts().reset_index().head(10)
# Out:
#                              Action Class  count
# 0            Cephalosporins: 3 generation  10901
# 1             Quinolones/ Fluroquinolones   7011
# 2   Fungal ergosterol synthesis inhibitor   5990
# 3                  Proton pump inhibitors   5734
# 4                              Macrolides   5109
# 5                         Glucocorticoids   4779
# 6  H1 Antihistaminics (second Generation)   3702
# 7            HMG CoA inhibitors (statins)   2561
# 8          Cephalosporins: 2nd generation   2448
# 9                         Benzodiazepines   2447

# %% [markdown]
# # Graph Construction

# %%
df_med = df_medications.drop(columns=['id']).copy(deep=True)
df_med.head()

# %%
# 1. Identify the columns to keep and those to transform
cols_to_keep = [col for col in df_med.columns if not col.startswith('substitute') and col != 'name']
cols_to_melt = ['name'] + [col for col in df_med.columns if col.startswith('substitute')]

# 2. Using pd.melt to transform the DataFrame
df_med_long = pd.melt(
    df_med,
    id_vars=cols_to_keep,
    value_vars=cols_to_melt,
    value_name='medication'
)

# 3. Clear the result
# Remove the 'variable' column that melt creates by default
df_med_long = df_med_long.drop(columns='variable')
# Remove rows where the new 'name' is null (originating from empty 'substitute' columns)
df_med_long = df_med_long.dropna(subset=['medication'])
# Resets the index to a clean sequence
df_med_long = df_med_long.reset_index(drop=True)

# Reorders columns to have 'medication' first (optional)
df_med_long = df_med_long[['medication'] + cols_to_keep]

# %%
df_med_long = df_med_long.drop_duplicates()
df_med_long

# %%
# Create the set of names
all_names = set(df_med_long['medication'].to_list())

# Total of unique names
print(len(all_names))
# Out:
# 269509

# %%
med_df = df_med_long[['medication']]
med_df

# %%
# 1. Identify the side effects columns
side_effect_cols = [col for col in df_med_long.columns if col.startswith('sideEffect')]

# 2. Use pd.melt to transform side effect columns
side_effects_long = pd.melt(
    df_med_long,
    value_vars=side_effect_cols,
    value_name='sideEffect'
)

# 3. Create the final DataFrame and clean it
# Select only the 'side Effect' column and remove null values
side_effects_df = (
    side_effects_long[['sideEffect']]
    .dropna()
    .drop_duplicates()
    .reset_index(drop=True)
)

side_effects_df

# %%
# Create the node dataframe in the cytoscape format
nodes_df = pd.concat(
    [
        pd.DataFrame({
            'id': med_df['medication'],
            'label': med_df['medication'],
            'type': 'medication'
        }),
        pd.DataFrame({
            'id': side_effects_df['sideEffect'],
            'label': side_effects_df['sideEffect'],
            'type': 'sideEffect'
        }),
    ]
).drop_duplicates()

nodes_df.to_csv("../data/interim/med-sideEffects-network-nodes.csv", index=False)

# %%
df_med_long.head(5)
# Out:
#                  medication sideEffect0       sideEffect1     sideEffect2  \
# 0  augmentin 625 duo tablet    Vomiting            Nausea        Diarrhea
# 1       azithral 500 tablet    Vomiting            Nausea  Abdominal pain
# 2          ascoril ls syrup      Nausea          Vomiting        Diarrhea
# 3      allegra 120mg tablet    Headache        Drowsiness       Dizziness
# 4            avil 25 tablet  Sleepiness  Dryness in mouth             NaN
#
#      sideEffect3   sideEffect4        sideEffect5 sideEffect6 sideEffect7  \
# 0            NaN           NaN                NaN         NaN         NaN
# 1       Diarrhea           NaN                NaN         NaN         NaN
# 2  Upset stomach  Stomach pain  Allergic reaction   Dizziness    Headache
# 3         Nausea           NaN                NaN         NaN         NaN
# 4            NaN           NaN                NaN         NaN         NaN
#
#   sideEffect8  ... sideEffect41  \
# 0         NaN  ...          NaN
# 1         NaN  ...          NaN
# 2        Rash  ...          NaN
# 3         NaN  ...          NaN
# 4         NaN  ...          NaN
#
#                                                 use0  \
# 0                  Treatment of Bacterial infections
# 1                  Treatment of Bacterial infections
# 2                      Treatment of Cough with mucus
# 3  Treatment of Sneezing and runny nose due to al...
# 4                   Treatment of Allergic conditions
#
#                                use1 use2 use3 use4  \
# 0                               NaN  NaN  NaN  NaN
# 1                               NaN  NaN  NaN  NaN
# 2                               NaN  NaN  NaN  NaN
# 3  Treatment of Allergic conditions  NaN  NaN  NaN
# 4                               NaN  NaN  NaN  NaN
#
#                Chemical Class Habit Forming Therapeutic Class  \
# 0                         NaN            No   ANTI INFECTIVES
# 1                  Macrolides            No   ANTI INFECTIVES
# 2                         NaN            No       RESPIRATORY
# 3  Diphenylmethane Derivative            No       RESPIRATORY
# 4       Pyridines Derivatives            No       RESPIRATORY
#
#                              Action Class
# 0                                     NaN
# 1                              Macrolides
# 2                                     NaN
# 3  H1 Antihistaminics (second Generation)
# 4   H1 Antihistaminics (First Generation)
#
# [5 rows x 52 columns]

# %%
# 1. Identify the columns to keep and those to transform
# id_vars: all columns that do NOT start with 'sideEffect'
id_vars = [col for col in df_med_long.columns if not col.startswith('sideEffect')]

# value_vars: all columns that BEGIN with 'sideEffect'
value_vars = [col for col in df_med_long.columns if col.startswith('sideEffect')]

# 2. Using pd.melt to transform the DataFrame
df_med_melted = pd.melt(
    df_med_long,
    id_vars=id_vars,
    value_vars=value_vars,
    value_name='target' # Name of the new column with the side effect values
)

# 3. Clear and rename the resulting DataFrame
# Remove the 'variable' column that melt creates and we don't need
df_med_melted = df_med_melted.drop(columns='variable')

# Removes rows where the side effect (target) is null
df_med_melted = df_med_melted.dropna(subset=['target'])

# Rename the 'medication' column to 'source'
df_med_melted = df_med_melted.rename(columns={'medication': 'source'})

# Reorder the columns to have 'source' and 'target' first (optional, but clearer)
cols_order = ['source', 'target'] + [col for col in df_med_melted.columns if col not in ['source', 'target']]
edge_df = df_med_melted[cols_order].reset_index(drop=True)

edge_df = edge_df.drop_duplicates().sort_values(by='source')

edge_df.to_csv("../data/interim/med-sideEffects-network-edges.csv", index=False)

# %%
# df_med.query('substitute0 == "Penciclav 500 mg/125 mg Tablet" | substitute1 == "Penciclav 500 mg/125 mg Tablet"')
